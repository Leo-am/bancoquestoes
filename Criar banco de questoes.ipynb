# %% [markdown]
# # Banco de questões

# %% [markdown]
# # Extraindo questões de um PDF

# %%
import criar_banco

# %%
PATH = ("/Users/leo/Documents/Github/bancoquestoes/Testes Questões/2022-FASE-1-Nível-B.pdf")
DELIMITER = "B."

questoes = criar_banco.extract_questions_from_pdf(PATH, DELIMITER)

# %%
numero_questao = 0

questao = questoes[0]
questao
# Out:
# '1)(somente para a 1ª série) Os aparelhos elétricos funcionam quando uma corrente elétrica passa\npor eles. Alguns equipamentos conseguem interromper automaticamente a passagem de corrente elétrica\nquando alcançam uma situação ideal. Um exemplo disso é o ferro de passar da casa de Jorge. Quando ele\natinge 120 °C, uma lâmina bimetálica retilínea encurva-se desfazendo o contato que permite a passagem de\ncorrente pelo ferro de passar, conforme mostra a figura. A lâmina bimetálica é composta por uma lâmina de\nferro e outra de latão justapostas e unidas fortemente.\nSabe-se que os coeficientes de dilatação linear do latão e do ferro são respectivamente iguais a 2,0x10-5°C-1 e\n1,2 x10-5 °C-1.Com base nessas informações, para que haja interrupção da corrente elétrica do ferro de passar:\na) a lâmina de ferro deve ficar acima da lâmina de latão.\nb) a lâmina de ferro deve ficar abaixo da lâmina de latão.\nc) a lâmina de ferro pode ficar acima ou abaixo da lâmina de latão.\nd) as duas lâminas devem ficar uma ao lado a outra.'

# %%
questao_completa = criar_banco.Questao(
    texto=questao,
    serie="Terceiro ano",
    origem="OBFEP 2022",
    dificuldade="7",
    imagem_path="/Users/leo/Documents/Github/bancoquestoes/Imagens/OBFEP2022/lamina_bimetalica", # Um caminho de arquivo
    temas=["Termometria", "Dilatação", "Lâmina Bimetálica"]           # Uma lista de strings
)

# %%
NOME_BANCO = "questoes_OBFEP"

criar_banco.create_database(NOME_BANCO)
# Out:
# Banco de dados 'questoes_OBFEP.db' e tabela 'questoes' criados/verificados.

# %%
# Informações que devem ser adicionadas ao banco de questões

# 1. Texto da questão.
# 2. Imagem da questão.
# 3. Origem da questão.
# 4. Tema(s) da questão.
# 5. Dificuldade da questão.
# 6. Série adequada para questão.

criar_banco.insert_question(NOME_BANCO, questao_completa)

# %% [markdown]
# ## Visualizar Banco de Questões

# %%
NOME_BANCO = "questoes_OBFEP"

# %%
criar_banco.checar_questoes_inseridas(NOME_BANCO, questoes)
# Out:
# --- CONSULTANDO DADOS na Tabela '['1)(somente para a 1ª série) Os aparelhos elétricos funcionam quando uma corrente elétrica passa\npor eles. Alguns equipamentos conseguem interromper automaticamente a passagem de corrente elétrica\nquando alcançam uma situação ideal. Um exemplo disso é o ferro de passar da casa de Jorge. Quando ele\natinge 120 °C, uma lâmina bimetálica retilínea encurva-se desfazendo o contato que permite a passagem de\ncorrente pelo ferro de passar, conforme mostra a figura. A lâmina bimetálica é composta por uma lâmina de\nferro e outra de latão justapostas e unidas fortemente.\nSabe-se que os coeficientes de dilatação linear do latão e do ferro são respectivamente iguais a 2,0x10-5°C-1 e\n1,2 x10-5 °C-1.Com base nessas informações, para que haja interrupção da corrente elétrica do ferro de passar:\na) a lâmina de ferro deve ficar acima da lâmina de latão.\nb) a lâmina de ferro deve ficar abaixo da lâmina de latão.\nc) a lâmina de ferro pode ficar acima ou abaixo da lâmina de latão.\nd) as duas lâminas devem ficar uma ao lado a outra.', '2) (somente para a 1ª série) No quarto de Ana existe uma janela com vidro transparente. Esse é um\nlocal da casa que a luz incide ao nascer do Sol. Para Ana, a luz que passa pela janela segue a trajetória\nrepresentada por uma linha tracejada na figura abaixo. Ana teve uma vontade de polvilhar talco na frente da\njanela para ver os raios de luz.\nCom base nas informações e no seu conhecimento sobre a óptica geométrica, pode-se afirmar que:\na) a forma do raio de luz é verdadeira por causa da gravidade.\nb) a forma do raio de luz corresponde ao princípio de propagação curvilínea da luz.\nc) a forma do raio de luz está errada, pois a luz propaga-se em linha reta.\nd) a trajetória da luz pode ser vista sem precisar de talco ou qualquer outra substância.\n', '3) (somente para a 1ª série)Certo dia, Claudio precisava de 2,0 kg de cimento, o qual seria retirado\nde um grande saco de cimento. Ele tinha duas balanças mecânicas, no quarto de bugigangas no fundo de sua\ncasa, representadas nas figuras. Uma era uma balança de pratos, que foi usada inicialmente. Ele colocou em\num prato padrões de massa que somados correspondiam a 2,0 kg. No outro prato, ele colocou cimento até a\nbalança equilibrar. Em seguida, colocou o cimento em um saco bem fino e pendurou-o no gancho da segunda\nbalança, a qual estava sendo mantida suspensa pela outra extremidade. Essa segunda balança tinha uma mola\nno seu interior. Quanto maior a massa presa no gancho, mais o indicador (cursor) descia. Ao parar de se\nmexer, o indicador registrava a massa do corpo pendurado pelo gancho. No caso, essa segunda balança\nmarcou 2,0 kg, validando a medida da primeira balança.\nNesse momento, Cláudio se questionou: “Se levasse essas balanças para a superfície da Lua e fizesse\nos mesmos procedimentos para obter 2,0 kg de cimento, elas indicariam a mesma quantidade de cimento que\nindicou aqui na superfície da Terra?”\nCom base nas informações, qual a resposta correta para o questionamento de Cláudio?\na) Nenhuma mediria 2,0 kg corretamente.\nb) As duas mediriam 2,0 kg corretamente.\nc) Apenas a balança de mola mediria 2,0 kg corretamente.\nd) Apenas a balança de pratos mediria 2,0 kg corretamente.\n', '4) (somente para a 1ª série) Na casa de João existiam várias máquinas simples: sistemas ou\nequipamentos que transmitem para um corpo o trabalho realizado neles. Geralmente, a função de uma\nmáquina simples é aplicar no corpo mais força que aquela aplicada pela pessoa na máquina simples. Das\nmáquinas simples encontradas na casa de João, qual é usada para executar uma função diferente da descrita?\na) Alicate\nb) Tesoura de unha\nc) Bicicleta\nd) Espremedor de batatas', '5) (somente para a 1ª série) Roberto é muito sensível à luz. Para\nconsegui dormir, pintou o vidro da janela do quarto de preto e colocou\numa cortina preta na porta. Dessa forma, o quarto ficou todo escuro. Certo\ndia, quando acordou, foi surpreendido c ...
#
# ❌ Erro ao consultar o banco de dados: no such table: '1)(somente para a 1ª série) Os aparelhos elétricos funcionam quando uma corrente elétrica passa\npor eles. Alguns equipamentos conseguem interromper automaticamente a passagem de corrente elétrica\nquando alcançam uma situação ideal. Um exemplo disso é o ferro de passar da casa de Jorge. Quando ele\natinge 120 °C, uma lâmina bimetálica retilínea encurva-se desfazendo o contato que permite a passagem de\ncorrente pelo ferro de passar, conforme mostra a figura. A lâmina bimetálica é composta por uma lâmina de\nferro e outra de latão justapostas e unidas fortemente.\nSabe-se que os coeficientes de dilatação linear do latão e do ferro são respectivamente iguais a 2,0x10-5°C-1 e\n1,2 x10-5 °C-1.Com base nessas informações, para que haja interrupção da corrente elétrica do ferro de passar:\na) a lâmina de ferro deve ficar acima da lâmina de latão.\nb) a lâmina de ferro deve ficar abaixo da lâmina de latão.\nc) a lâmina de ferro pode ficar acima ou abaixo da lâmina de latão.\nd) as duas lâminas devem ficar uma ao lado a outra.', '2) (somente para a 1ª série) No quarto de Ana existe uma janela com vidro transparente. Esse é um\nlocal da casa que a luz incide ao nascer do Sol. Para Ana, a luz que passa pela janela segue a trajetória\nrepresentada por uma linha tracejada na figura abaixo. Ana teve uma vontade de polvilhar talco na frente da\njanela para ver os raios de luz.\nCom base nas informações e no seu conhecimento sobre a óptica geométrica, pode-se afirmar que:\na) a forma do raio de luz é verdadeira por causa da gravidade.\nb) a forma do raio de luz corresponde ao princípio de propagação curvilínea da luz.\nc) a forma do raio de luz está errada, pois a luz propaga-se em linha reta.\nd) a trajetória da luz pode ser vista sem precisar de talco ou qualquer outra substância.\n', '3) (somente para a 1ª série)Certo dia, Claudio precisava de 2,0 kg de cimento, o qual seria retirado\nde um grande saco de cimento. Ele tinha duas balanças mecânicas, no quarto de bugigangas no fundo de sua\ncasa, representadas nas figuras. Uma era uma balança de pratos, que foi usada inicialmente. Ele colocou em\num prato padrões de massa que somados correspondiam a 2,0 kg. No outro prato, ele colocou cimento até a\nbalança equilibrar. Em seguida, colocou o cimento em um saco bem fino e pendurou-o no gancho da segunda\nbalança, a qual estava sendo mantida suspensa pela outra extremidade. Essa segunda balança tinha uma mola\nno seu interior. Quanto maior a massa presa no gancho, mais o indicador (cursor) descia. Ao parar de se\nmexer, o indicador registrava a massa do corpo pendurado pelo gancho. No caso, essa segunda balança\nmarcou 2,0 kg, validando a medida da primeira balança.\nNesse momento, Cláudio se questionou: “Se levasse essas balanças para a superfície da Lua e fizesse\nos mesmos procedimentos para obter 2,0 kg de cimento, elas indicariam a mesma quantidade de cimento que\nindicou aqui na superfície da Terra?”\nCom base nas informações, qual a resposta correta para o questionamento de Cláudio?\na) Nenhuma mediria 2,0 kg corretamente.\nb) As duas mediriam 2,0 kg corretamente.\nc) Apenas a balança de mola mediria 2,0 kg corretamente.\nd) Apenas a balança de pratos mediria 2,0 kg corretamente.\n', '4) (somente para a 1ª série) Na casa de João existiam várias máquinas simples: sistemas ou\nequipamentos que transmitem para um corpo o trabalho realizado neles. Geralmente, a função de uma\nmáquina simples é aplicar no corpo mais força que aquela aplicada pela pessoa na máquina simples. Das\nmáquinas simples encontradas na casa de João, qual é usada para executar uma função diferente da descrita?\na) Alicate\nb) Tesoura de unha\nc) Bicicleta\nd) Espremedor de batatas', '5) (somente para a 1ª série) Roberto é muito sensível à luz. Para\nconsegui dormir, pintou o vidro da janela do quarto de preto e colocou\numa cortina preta na porta. Dessa forma, o quarto ficou todo escuro. Certo\ndia, quando acordou, ...
# []

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect(f'{NOME_BANCO}.db')
query = "SELECT * FROM questoes"
df = pd.read_sql_query(query, conn)

# Exibe o DataFrame como uma tabela no Jupyter Lab
df.head()  # ou df para visualizar a tabela completa
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 2
#       1 import sqlite3
# ----> 2 import pandas as pd
#       3 conn = sqlite3.connect(f'{NOME_BANCO}.db')
#       4 query = "SELECT * FROM questoes"
#
# ModuleNotFoundError: No module named 'pandas'

# %%
tema_especifico = "optica"
df_filtrado = df[df['tema'] == tema_especifico]
df_filtrado.head()
# Out:
#     id                                              texto    tema dificuldade  \
# 1    2  2) (somente para a 1ª série) No quarto de Ana ...  optica   a definir
# 5    6  5) (somente para a 1ª série) Roberto é muito s...  optica   a definir
# 16  17  15) Quando a porta e as janelas do escritório ...  optica   a definir
# 18  19  17) Adalberto sente-se mais à vontade quando c...  optica   a definir
#
#     serie
# 1   1 ano
# 5   1 ano
# 16  2 ano
# 18  2 ano

# %%
def visualizar_questao(id_questao):
    # Conecta ao banco de dados SQLite
    conn = sqlite3.connect(f'{NOME_BANCO}.db')
    
    # Consulta SQL para buscar a questão pelo ID
    query = f"""
    SELECT serie, tema, dificuldade, texto 
    FROM questoes 
    WHERE id = {id_questao}
    """
    
    # Executa a consulta e carrega o resultado em um DataFrame
    df = pd.read_sql_query(query, conn)
    
    # Fecha a conexão com o banco de dados
    conn.close()
    
    # Verifica se a questão foi encontrada
    if df.empty:
        print(f"Nenhuma questão encontrada com o ID {id_questao}.")
        return
    
    # Extrai os dados da questão
    ano = df['serie'].iloc[0]
    tema = df['tema'].iloc[0]
    dificuldade = df['dificuldade'].iloc[0]
    texto = df['texto'].iloc[0]
    
    # Formata e exibe o resultado
    print(f"Ano: {ano}")
    print(f"Tema: {tema}")
    print(f"Dificuldade: {dificuldade}")
    print(f"Texto: {texto}")

# Exemplo de uso
visualizar_questao(1)
# Out:
# Ano: 2 ano
# Tema: termodinâmica
# Dificuldade: a definir
# Texto: 1)(somente para a 1ª série) Os aparelhos elétricos funcionam quando uma corrente elétrica passa
# por eles. Alguns equipamentos conseguem interromper automaticamente a passagem de corrente elétrica
# quando alcançam uma situação ideal. Um exemplo disso é o ferro de passar da casa de Jorge. Quando ele
# atinge 120 °C, uma lâmina bimetálica retilínea encurva-se desfazendo o contato que permite a passagem de
# corrente pelo ferro de passar, conforme mostra a figura. A lâmina bimetálica é composta por uma lâmina de
# ferro e outra de latão justapostas e unidas fortemente.
# Sabe-se que os coeficientes de dilatação linear do latão e do ferro são respectivamente iguais a 2,0x10-5°C-1 e
# 1,2 x10-5 °C-1.Com base nessas informações, para que haja interrupção da corrente elétrica do ferro de passar:
# a) a lâmina de ferro deve ficar acima da lâmina de latão.
# b) a lâmina de ferro deve ficar abaixo da lâmina de latão.
# c) a lâmina de ferro pode ficar acima ou abaixo da lâmina de latão.
# d) as duas lâminas devem ficar uma ao lado a outra.

# %% [markdown]
# ## Criando uma lista a partir de um banco de dados

# %%
import criar_lista
# Out:
# /Users/leoassis/opt/miniconda3/envs/questoes/lib/python3.12/site-packages/fpdf/__init__.py:39: UserWarning: You have both PyFPDF & fpdf2 installed. Both packages cannot be installed at the same time as they share the same module namespace. To only keep fpdf2, run: pip uninstall --yes pypdf && pip install --upgrade fpdf2
#   warnings.warn(

# %%
NOME_BANCO = "questoes_OBFEP"

questoes = criar_lista.fetch_questions(NOME_BANCO)

# %%
criar_lista.create_pdf(questoes, "teste.pdf")

# %% [markdown]
# # END OF NOTEBOOK
