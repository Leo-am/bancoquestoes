# %% [markdown]
# # Criar Lista a partir do banco de dados

# %%
import sys
import os

# Adiciona a pasta raiz do projeto ao path
sys.path.append(os.path.abspath(os.path.join('..')))

from src import gerador

# %%
from src import gerador

NOME_DO_BANCO = "questoes_OBFEP" # Use o nome do seu banco

# Executa a função
gerador.gerar_lista_exercicios_latex(
    nome_do_banco=NOME_DO_BANCO,
    tema="Calorimetria",
    nome_arquivo="Lista_Calorimetria"
)
# Out:
# ❌ Erro ao buscar questões por tema: no such table: questoes
# ⚠️ Nenhuma questão encontrada para o tema 'Calorimetria'. Arquivo LaTeX não gerado.

# %% [markdown]
# # END OF NOTEBOOK
